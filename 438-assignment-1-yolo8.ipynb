# %%
# !pip install -qU "numpy<2.0" "opencv-python-headless==4.10.*"
# !pip install -qU ultralytics --no-deps
# !pip install ruamel.yaml
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.7 MB/s eta 0:00:00
# Collecting ruamel.yaml
#   Downloading ruamel.yaml-0.18.16-py3-none-any.whl.metadata (25 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml)
#   Downloading ruamel_yaml_clib-0.2.15-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Downloading ruamel.yaml-0.18.16-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 8.3 MB/s eta 0:00:00
# Downloading ruamel_yaml_clib-0.2.15-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (777 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 777.6/777.6 kB 47.5 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, ruamel.yaml
# Successfully installed ruamel.yaml-0.18.16 ruamel.yaml.clib-0.2.15

# %% [markdown]
# # **Move dataset to working directory**

# %%
# !cp -r "/kaggle/input/waste-detection/waste detection data/" "/kaggle/working/dataset"

# %% [markdown]
# # Generating yaml config file for yolo

# %%
from ruamel.yaml import YAML
import os

ROOT_TRAINING_FOLDER = "/kaggle/working/dataset"
# Correct the paths in the data dictionary
data = {
    'train': os.path.join(ROOT_TRAINING_FOLDER, 'train', 'images'),
    'val': os.path.join(ROOT_TRAINING_FOLDER, 'valid', 'images'),
    'nc': 7,
    'names': ['Aluminium', 'Glass', 'Tag', 'cardboard', 'rigid_plastic', 'soft_plastic', 'wood']
}

yaml = YAML()
with open('data.yaml', 'w') as f:
    yaml.dump(data, f)

# %% [markdown]
# # Check and verify dataset

# %%
from ultralytics.data.utils import check_det_dataset

check_det_dataset('/kaggle/working/data.yaml')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 124.8MB/s 0.0s
# {'train': '/kaggle/working/dataset/train/images',
#  'val': '/kaggle/working/dataset/valid/images',
#  'nc': 7,
#  'names': {0: 'Aluminium',
#   1: 'Glass',
#   2: 'Tag',
#   3: 'cardboard',
#   4: 'rigid_plastic',
#   5: 'soft_plastic',
#   6: 'wood'},
#  'yaml_file': '/kaggle/working/data.yaml',
#  'channels': 3,
#  'path': PosixPath('/kaggle/working')}

# %%
# FOR CLEANUP ONLY
# !rm yolo11n.pt
# !rm yolo11n-seg.pt
# !rm yolo11s-seg.pt
# !rm yolo11s-seg.pt
# !rm yolov8n-seg.pt
# !rm yolo12n.pt
# !rm -rf yolo12_runs
# !rm -rf runs

# %% [markdown]
# # Training yolov8n-seg

# %%
from ultralytics import YOLO

DATA_YAML = "/kaggle/working/data.yaml"

# COMMON VARS
MODEL_NAME = "yolov8n-seg.pt"
SAVE_NAME = "waste_yolov8n_seg"
EPOCHS = 20

# Load a pre-trained YOLOv8 segmentation model
model = YOLO(MODEL_NAME)

results = model.train(
    data=DATA_YAML,
    epochs=EPOCHS,           
    imgsz=640,
    batch=8,             
    workers=2,
    device=0,            
    patience=10,          # early stopping
    save=True,
    save_period=5,       # set >0 to save every N epochs
    pretrained=True,
    optimizer="auto",
    name=SAVE_NAME,
    exist_ok=True,
    amp=False,
    # resume=True,
    
)

# Train the model with caching disabled, reduced epochs, and on GPU
# results = model.train(data=DATA_YAML, epochs=5, imgsz=640, cache=False, amp=False, device='0')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n-seg.pt to 'yolov8n-seg.pt': 100% ━━━━━━━━━━━━ 6.7MB 257.8MB/s 0.0s
# Ultralytics 8.3.233 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: agnostic_nms=False, amp=False, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=waste_yolov8n_seg, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/segment/waste_yolov8n_seg, save_frames=False, save_json=False, save_period=5, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1   1005445  ultralytics.nn.modules.head.Segment          [7, 32, 64, [64, 128, 256]]
# YOLOv8n-seg summary: 151 layers, 3,264,981 parameters, 3,264,965 gradients
#
# Transferred 381/417 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1619.3±507.1 MB/s, size: 137.1 KB)
# train: Scanning /kaggle/working/dataset/train/labels... 7820 images, 8295 backgrounds, 56 corrupt: 100% ━━━━━━━━━━━━ 16073/16073 1.5Kit/s 10.4s
# train: /kaggle/working/dataset/train/images/01_frame_047600_PNG.rf.61e65ac5cacb536cdda1b9d59fb0a361.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0396]
# train: /kaggle/working/dataset/train/images/03_frame_036700_PNG.rf.13008f0b16f187c3d35ff2cac7da5bf3.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/03_frame_036700_PNG.rf.eeb2e6a8d23c411472f3376d54563be6.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/05_frame_043600_PNG.rf.0f35379e45fae22a643bdd3590521662.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/07_frame_042600_PNG.rf.a041b8abe12cf301eaffceb35449669f.jpg: 2 duplicate labels removed
# train: /kaggle/working/dataset/train/images/08_frame_000551_PNG.rf.0d58c914145dded39825c87b61134eda.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1186]
# train: /kaggle/working/dataset/train/images/08_frame_011900_PNG.rf.7dc615bddae823b082a2edf47cc26c9a.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/08_frame_011900_PNG.rf.b4d0d59ad3f25986fa541ba94042fdd5.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/08_frame_012000_PNG.rf.1cfecb2ebb70f1f73d8c1f475f28a897.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/08_frame_012000_PNG.rf.cd421b34ff1d4a67dabc141617022d53.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/08_frame_012300_PNG.rf.41c9433b12f5c61da4a16fd4636d71f2.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/09_frame_003040_PNG.rf.5f782661d227b778a07faf40657558d0.jpg: 3 duplicate labels removed
# train: /kaggle/working/dataset/train/images/09_frame_003090_PNG.rf.eb6853ac6f642c5bb243a487cea03199.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/09_frame_003120_PNG.rf.cd4ee1fa844e5c91e7c766c468ca40b9.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/09_frame_035200_PNG.rf.dc492625d29c40a61bb63922164b465b.jpg: 3 duplicate labels removed
# train: /kaggle/working/dataset/train/images/10_frame_000871_PNG.rf.f921035023b319c35bf5b60a3ce5d459.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/10_frame_045600_PNG.rf.88d815b63cf2f27a04c1f4411d4d51f9.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/AluCan112_jpg.rf.f93b7ead84bb1ab109dd1c47a74ef9a8.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0491]
# train: /kaggle/working/dataset/train/images/AluCan113_jpg.rf.50e1ad8a216dbaab54f3670f0047aedb.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2468]
# train: /kaggle/working/dataset/train/images/AluCan17_jpg.rf.e8c660b2afd30c10e6478aaea5ca8e05.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0977      1.0209]
# train: /kaggle/working/dataset/train/images/AluCan85_jpg.rf.ed45e1b4ffa2dbf95ccfd9c0be81b1b3.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0701      1.1094]
# train: /kaggle/working/dataset/train/images/Glass109_jpg.rf.bb5ed700551717ad305a7e65e8d37682.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0876      1.1922]
# train: /kaggle/working/dataset/train/images/Glass117_jpg.rf.e55fca54c105b7c04c3fe3e1dc84e50e.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.14]
# train: /kaggle/working/dataset/train/images/Glass118_jpg.rf.684ab30477fc040f9b79d359055396f5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1051]
# train: /kaggle/working/dataset/train/images/Glass119_jpg.rf.8b4566211b1bd5dd3e08975aa5c426ce.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0374]
# train: /kaggle/working/dataset/train/images/Glass124_jpg.rf.0a25089882ad53e1b941f122eac04898.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0308]
# train: /kaggle/working/dataset/train/images/Glass12_jpg.rf.228ff81e4e131c5af7357928561dc3c3.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1286      1.1412]
# train: /kaggle/working/dataset/train/images/Glass133_jpg.rf.ed9a83c7886c38636057c5dd64c4078f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0604]
# train: /kaggle/working/dataset/train/images/Glass151_jpg.rf.b190a298681c3b6b166ca4331b8df064.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1727]
# train: /kaggle/working/dataset/train/images/Glass154_jpg.rf.7ba59512b72d6bc204b755bd81a98da6.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0399]
# train: /kaggle/working/dataset/train/images/Glass290_jpg.rf.f85c647f3c1fd76dc8fe0cafbc1f5251.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2008]
# train: /kaggle/working/dataset/train/images/Glass321_jpg.rf.1ef3e2b5d4c49ef05d4145c0483bef99.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0586]
# train: /kaggle/working/dataset/train/images/Glass35_jpg.rf.102a7a9deda0db103e904735872e78ee.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1496       1.085]
# train: /kaggle/working/dataset/train/images/Glass383_jpg.rf.582d1d265d26d14088fccad7344e9305.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0455]
# train: /kaggle/working/dataset/train/images/Glass389_jpg.rf.3235a550d4955a229bc299974519b982.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0261]
# train: /kaggle/working/dataset/train/images/Glass42_jpg.rf.14cd2c9f66e5d6209287b9fb5cbb6ada.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0234      1.1748]
# train: /kaggle/working/dataset/train/images/Glass485_jpg.rf.7921e99c39eb6ee4228376fcd459f7b0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0548]
# train: /kaggle/working/dataset/train/images/Glass49_jpg.rf.3f660a681976ceadd26403062c38f00f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0818]
# train: /kaggle/working/dataset/train/images/Glass61_jpg.rf.4afddebca509a4cde91c5d35db8c9381.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0561]
# train: /kaggle/working/dataset/train/images/Glass67_jpg.rf.e1b50033e29d6c87f19ac9db766be3bc.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1307]
# train: /kaggle/working/dataset/train/images/Glass72_jpg.rf.b5ee8d507d6ac4c04216cae5441e2da7.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.021]
# train: /kaggle/working/dataset/train/images/Glass74_jpg.rf.ce954f787fcfa768bbbe19dfbb3e6d11.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0193]
# train: /kaggle/working/dataset/train/images/Glass75_jpg.rf.b6e587a8b645dc14210ed8abc81c9e78.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0154]
# train: /kaggle/working/dataset/train/images/HDPEM33_jpg.rf.578b8682827bcc25e4979077927201ab.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0176]
# train: /kaggle/working/dataset/train/images/Image__2023-02-20__13-17-08_bmp_jpg.rf.d204f2be498e8ca3d830eb5b0d231326.jpg: 2 duplicate labels removed
# train: /kaggle/working/dataset/train/images/Image__2023-02-22__16-20-21_bmp_jpg.rf.b10f0473e0f6767ad7c1dac42608ecaf.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0112]
# train: /kaggle/working/dataset/train/images/Image__2023-02-22__16-48-46_bmp_jpg.rf.f34d7f7e6671bc96c915d48298e9c8d6.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5347      1.4036]
# train: /kaggle/working/dataset/train/images/Image__2023-02-22__17-02-58_bmp_jpg.rf.ea3d1fdbf426ab0b04d00f2fbd61973b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1265]
# train: /kaggle/working/dataset/train/images/PET1-522_jpg.rf.3d7eb21faccff2da6f5091b8fc074a65.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0541      1.1312]
# train: /kaggle/working/dataset/train/images/PET1-539_jpg.rf.df5e9a8c966fe783a16b189cd984c2f5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1563]
# train: /kaggle/working/dataset/train/images/PET1-543_jpg.rf.cea22eb446e761ddcdadcd729deeaf3f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0282]
# train: /kaggle/working/dataset/train/images/PET1-544_jpg.rf.c3baf4669cfa9d5ac843c5ea00ba0efd.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.145]
# train: /kaggle/working/dataset/train/images/PET1-547_jpg.rf.d357ea5e6212a5c2ede066bbef51798d.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3094      1.0529]
# train: /kaggle/working/dataset/train/images/PET1-548_jpg.rf.3bc268e050cfe366234a3fa030b13e75.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0649]
# train: /kaggle/working/dataset/train/images/PET1-549_jpg.rf.10622ac4db0cb82eace7ca2164bbb1d2.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1376]
# train: /kaggle/working/dataset/train/images/PET1-550_jpg.rf.229ac61fd68471779caaef6d397d254b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1814]
# train: /kaggle/working/dataset/train/images/PET1-575_jpg.rf.a5272fdc61b5d75476029c14e34a0af1.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0277]
# train: /kaggle/working/dataset/train/images/PET1-583_jpg.rf.b54958635200753cecf26c47b797d53a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0557]
# train: /kaggle/working/dataset/train/images/PET1-585_jpg.rf.ade62805962a79c6ecf908f657c5cb05.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1103]
# train: /kaggle/working/dataset/train/images/PET1-586_jpg.rf.8d6eef04cc63ebe65f5a0c05de58f08f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0406]
# train: /kaggle/working/dataset/train/images/PET1-590_jpg.rf.7ce3ea166a77989f844ca0e864deb1e0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0349]
# train: /kaggle/working/dataset/train/images/PET1-598_jpg.rf.c3648d2471d1260a58542ac54f4ba536.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1022]
# train: /kaggle/working/dataset/train/images/PET1-607_jpg.rf.78902e1ac0e64f1d837eb351c40f7a5a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0303]
# train: /kaggle/working/dataset/train/images/PET1-621_jpg.rf.c37bad8e23eb4a1e9cb9396688807d78.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0664]
# train: /kaggle/working/dataset/train/images/PET1-669_jpg.rf.2a959f6ef26e1ce49263157a7e90ff75.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0381]
# train: /kaggle/working/dataset/train/images/PET1-684_jpg.rf.3276ba06538c6bf113eac0fef280832b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0912]
# train: /kaggle/working/dataset/train/images/PET1-686_jpg.rf.9ac075fed671462b9e3025aa6d3c0469.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0754]
# train: /kaggle/working/dataset/train/images/PET1-687_jpg.rf.6a5141941734e9b424949da0867fbb44.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1063]
# train: /kaggle/working/dataset/train/images/PET1-688_jpg.rf.36b4cb1f0a98293af8c8cdf0cff003b3.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0162]
# train: /kaggle/working/dataset/train/images/PET1-694_jpg.rf.bf5103bee818aa21e3479fe2f2ee93fd.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0448]
# train: /kaggle/working/dataset/train/images/PET1-698_jpg.rf.aae2e739acf3092ba6d8c91e69547d2f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.23]
# train: /kaggle/working/dataset/train/images/PET1-711_jpg.rf.91e87881bd16f7443693edf295cd9f30.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0334]
# train: /kaggle/working/dataset/train/images/PET434_jpg.rf.6dc54bf8bd63688fad93645dcbfdea7f.jpg: 2 duplicate labels removed
# train: /kaggle/working/dataset/train/images/PET448_jpg.rf.ce454fdb340b916d406ab7a1985c93c3.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/PET454_jpg.rf.8cd258d1f9aea52e313b41620951327b.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/PET457_jpg.rf.9b9960bbe6fe749fc8358ad0896f00e0.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/PET465_jpg.rf.db5531865e2f0b499dd8eed7e956f573.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/PET489_jpg.rf.29b3d5dfc0c9380cc71137797d98ce1f.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/PET500_jpg.rf.02c34cdeebf32236846e45a4c704b3d6.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/PET512_jpg.rf.7898bd87da844b989ecec344acbe28a6.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/PET517_jpg.rf.296a943d440825e27cdaea5ddff76c33.jpg: 1 duplicate labels removed
# train: /kaggle/working/dataset/train/images/PET523_jpg.rf.f0337cb18d2612143ea3a94bf359c818.jpg: 1 duplicate labels removed
# train: New cache created: /kaggle/working/dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 600.2±425.9 MB/s, size: 67.0 KB)
# val: Scanning /kaggle/working/dataset/valid/labels... 1290 images, 9 backgrounds, 20 corrupt: 100% ━━━━━━━━━━━━ 1290/1290 995.0it/s 1.3s
# val: /kaggle/working/dataset/valid/images/01_frame_040300_PNG.rf.c5140dc39296ee80931c1cc0c3cee9ee.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0881]
# val: /kaggle/working/dataset/valid/images/08_frame_012100_PNG.rf.f4b2be3bc7ee1a3c5cd806a515abbd02.jpg: 3 duplicate labels removed
# val: /kaggle/working/dataset/valid/images/AluCan29_jpg.rf.931d106191ef0eeb3f63ce3556281b8b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.052]
# val: /kaggle/working/dataset/valid/images/Glass107_jpg.rf.2f4f1734eee603a601c916ae5a32d501.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0615]
# val: /kaggle/working/dataset/valid/images/Glass128_jpg.rf.673fb32f860feb4848d5a148cbbf32c9.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2417]
# val: /kaggle/working/dataset/valid/images/Glass138_jpg.rf.76a2ac8e1838fb6c01c99b5071eb0ca9.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0137]
# val: /kaggle/working/dataset/valid/images/Glass142_jpg.rf.4c2629d042d2b3448e7ebd17d59cf9a8.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.222]
# val: /kaggle/working/dataset/valid/images/Glass278_jpg.rf.207f90ac467970e1ac71ad2e9386bf47.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2458]
# val: /kaggle/working/dataset/valid/images/Glass412_jpg.rf.ba16ca0c33e4f1c975164f21c32a8dfa.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0182]
# val: /kaggle/working/dataset/valid/images/Glass479_jpg.rf.097ae1546aa8f27a310a6fad350331eb.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1384      1.2161]
# val: /kaggle/working/dataset/valid/images/Glass498_jpg.rf.06e48e39b6cb7fb3ac9f66f74fd2a2f0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1478]
# val: /kaggle/working/dataset/valid/images/Glass62_jpg.rf.63d80aa4670ec62cbe1ba05ceb6708a9.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3604      1.4424]
# val: /kaggle/working/dataset/valid/images/Glass65_jpg.rf.c31e41898cbc71a1102582456966f5fa.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1677      1.0856]
# val: /kaggle/working/dataset/valid/images/HDPEM35_jpg.rf.c30029f738b5b17207de5c166a95c7c7.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1182      1.0338]
# val: /kaggle/working/dataset/valid/images/Image__2023-02-22__16-53-37_bmp_jpg.rf.a90e1e71c5159411ef31c6358b6604ef.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1523      1.1715]
# val: /kaggle/working/dataset/valid/images/PET1-537_jpg.rf.fda8c3cf28284371176769a9b9962e94.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1228]
# val: /kaggle/working/dataset/valid/images/PET1-594_jpg.rf.75cc97f7e6f7ffb22073c7672621e85b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0458]
# val: /kaggle/working/dataset/valid/images/PET1-606_jpg.rf.20a55da28ac397b412e24a2224a50e6b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0526]
# val: /kaggle/working/dataset/valid/images/PET1-610_jpg.rf.68134c59a3a8d70c42d9f737a2a0cdd2.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0733]
# val: /kaggle/working/dataset/valid/images/PET1-654_jpg.rf.d0c99106fb86dfd1f0171483d2bf6200.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0137]
# val: /kaggle/working/dataset/valid/images/PET1-660_jpg.rf.5a94be46b51ed1c6e2035eb8555d03b9.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0124]
# val: New cache created: /kaggle/working/dataset/valid/labels.cache
# Plotting labels to /kaggle/working/runs/segment/waste_yolov8n_seg/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000909, momentum=0.9) with parameter groups 66 weight(decay=0.0), 77 weight(decay=0.0005), 76 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/segment/waste_yolov8n_seg
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      2.73G       1.61      3.376      3.129      1.575         15        640: 100% ━━━━━━━━━━━━ 2003/2003 5.6it/s 5:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 5.7it/s 14.1s
#                    all       1270       4483      0.431      0.414       0.34      0.202      0.395      0.414      0.291      0.125
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      2.87G      1.605      3.163      2.686      1.581          2        640: 100% ━━━━━━━━━━━━ 2003/2003 5.8it/s 5:45
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s
#                    all       1270       4483      0.446      0.436      0.416      0.245      0.426      0.413      0.368      0.189
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      2.89G      1.586      3.106      2.548      1.577          1        640: 100% ━━━━━━━━━━━━ 2003/2003 5.8it/s 5:46
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 5.8it/s 13.9s
#                    all       1270       4483      0.433      0.501      0.453      0.278      0.419      0.494      0.429       0.22
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/20       2.9G      1.555       3.06      2.486      1.556          4        640: 100% ━━━━━━━━━━━━ 2003/2003 5.8it/s 5:46
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 5.7it/s 14.1s
#                    all       1270       4483      0.515      0.531      0.462       0.28      0.495      0.511      0.425      0.221
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      2.91G      1.502      2.974      2.365      1.524          7        640: 100% ━━━━━━━━━━━━ 2003/2003 5.8it/s 5:46
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s
#                    all       1270       4483      0.589      0.578      0.549      0.337      0.585      0.559       0.54      0.273
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      2.94G      1.472      2.902      2.315      1.505          4        640: 100% ━━━━━━━━━━━━ 2003/2003 5.8it/s 5:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s
#                    all       1270       4483      0.557      0.591      0.581      0.381      0.539      0.571      0.558      0.319
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      2.96G       1.44      2.858      2.269      1.483          7        640: 100% ━━━━━━━━━━━━ 2003/2003 5.9it/s 5:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s
#                    all       1270       4483      0.589      0.588      0.604       0.39       0.57      0.559      0.562      0.323
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      2.98G      1.418      2.809      2.223      1.469          8        640: 100% ━━━━━━━━━━━━ 2003/2003 5.9it/s 5:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 6.1it/s 13.2s
#                    all       1270       4483      0.577      0.634      0.589      0.382      0.559       0.61      0.559      0.323
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        9/20         3G      1.382      2.769       2.16       1.44          7        640: 100% ━━━━━━━━━━━━ 2003/2003 5.8it/s 5:45
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s
#                    all       1270       4483      0.693      0.628      0.667      0.449      0.669      0.606      0.627      0.376
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      3.01G      1.374      2.742      2.152       1.44          6        640: 100% ━━━━━━━━━━━━ 2003/2003 5.8it/s 5:44
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s
#                    all       1270       4483      0.655      0.649      0.662      0.452      0.637      0.621       0.63      0.381
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      3.03G      1.308      2.612       2.33       1.43          8        640: 100% ━━━━━━━━━━━━ 2003/2003 6.0it/s 5:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.2s
#                    all       1270       4483      0.638      0.637      0.645      0.444      0.622      0.617      0.614      0.377
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      3.05G      1.283      2.575      2.224      1.414          0        640: 100% ━━━━━━━━━━━━ 2003/2003 6.1it/s 5:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 6.1it/s 13.1s
#                    all       1270       4483      0.645      0.642      0.679      0.472      0.629      0.622      0.645      0.399
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      3.06G       1.26      2.522      2.278      1.391         10        640: 100% ━━━━━━━━━━━━ 2003/2003 6.0it/s 5:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s
#                    all       1270       4483      0.689      0.654      0.689      0.489      0.676      0.637      0.657      0.416
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      3.09G      1.251      2.506      2.144      1.391          0        640: 100% ━━━━━━━━━━━━ 2003/2003 6.0it/s 5:33
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s
#                    all       1270       4483      0.713      0.649      0.699      0.495      0.699      0.631      0.667      0.424
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      3.11G      1.223      2.469      2.229      1.364          5        640: 100% ━━━━━━━━━━━━ 2003/2003 6.0it/s 5:33
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s
#                    all       1270       4483       0.73      0.654      0.706      0.519      0.715      0.639      0.677      0.435
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      3.12G      1.202      2.414      2.174       1.35          0        640: 100% ━━━━━━━━━━━━ 2003/2003 6.0it/s 5:33
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s
#                    all       1270       4483      0.718       0.68       0.71      0.515      0.708      0.661      0.681      0.443
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      3.15G      1.192      2.398      2.025      1.342          4        640: 100% ━━━━━━━━━━━━ 2003/2003 6.0it/s 5:33
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.3s
#                    all       1270       4483      0.719      0.685      0.723      0.533      0.703      0.669      0.692      0.449
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      3.16G      1.165      2.379      2.122      1.325          0        640: 100% ━━━━━━━━━━━━ 2003/2003 6.0it/s 5:33
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s
#                    all       1270       4483      0.747      0.665      0.726      0.536      0.733      0.647      0.695      0.455
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      3.18G      1.151      2.349       2.05       1.32          9        640: 100% ━━━━━━━━━━━━ 2003/2003 6.0it/s 5:33
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s
#                    all       1270       4483      0.745      0.675      0.735      0.545      0.732      0.661      0.705      0.461
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       20/20       3.2G      1.141      2.318      2.068      1.307         10        640: 100% ━━━━━━━━━━━━ 2003/2003 6.0it/s 5:33
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.2s
#                    all       1270       4483       0.74       0.69       0.73      0.543      0.726      0.675        0.7      0.459
#
# 20 epochs completed in 1.960 hours.
# Optimizer stripped from /kaggle/working/runs/segment/waste_yolov8n_seg/weights/last.pt, 6.8MB
# Optimizer stripped from /kaggle/working/runs/segment/waste_yolov8n_seg/weights/best.pt, 6.8MB
#
# Validating /kaggle/working/runs/segment/waste_yolov8n_seg/weights/best.pt...
# Ultralytics 8.3.233 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,259,429 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.7s
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all       1270       4483      0.745      0.675      0.734      0.545      0.732      0.661      0.705      0.461
#              Aluminium        151        154      0.867      0.714      0.786       0.63      0.868      0.714      0.786       0.58
#                  Glass        104        116      0.778       0.75      0.846      0.663      0.761      0.733        0.8       0.49
#                    Tag        267        301      0.722      0.817      0.811      0.574      0.717      0.811      0.803      0.528
#              cardboard        566       2312       0.64      0.456      0.524      0.311      0.614      0.435      0.485      0.224
#          rigid_plastic        609        682      0.859      0.688      0.773      0.615      0.855      0.685      0.763      0.468
#           soft_plastic        429        895      0.623      0.301      0.406       0.22      0.616      0.293      0.382      0.157
#                   wood         23         23      0.724          1      0.995      0.802      0.693      0.957      0.919      0.779
# Speed: 0.2ms preprocess, 3.0ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to /kaggle/working/runs/segment/waste_yolov8n_seg

# %% [markdown]
# # Visualizing And Validating the model

# %%
import os
import glob
import json
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

RUN_BASES = [
    "/kaggle/working/runs/segment",
]
TARGET_RUN_NAME = SAVE_NAME 
OUT_CSV = "/kaggle/working/final_metrics_summary.csv"

def find_run_dirs(bases, run_name):
    runs = []
    for base in bases:
        candidate = os.path.join(base, run_name)
        if os.path.isdir(candidate):
            runs.append(candidate)
        else:
            if os.path.isdir(base):
                subs = sorted(glob.glob(os.path.join(base, "*")), key=os.path.getmtime, reverse=True)
                for s in subs:
                    if run_name in os.path.basename(s):
                        runs.append(s)
                        break
    return runs

def load_metrics(run_dir):
    # look for common metrics files
    candidates = [
        os.path.join(run_dir, "metrics.csv"),
        os.path.join(run_dir, "results.csv"),
        os.path.join(run_dir, "metrics.json"),
        os.path.join(run_dir, "results.json"),
    ]
    # add any metrics-like files found recursively
    candidates += glob.glob(os.path.join(run_dir, "**", "*metrics*.csv"), recursive=True)
    candidates += glob.glob(os.path.join(run_dir, "**", "*.json"), recursive=True)
    seen = set()
    for p in candidates:
        if not p or p in seen:
            continue
        seen.add(p)
        if os.path.exists(p):
            try:
                if p.endswith(".csv"):
                    df = pd.read_csv(p)
                else:
                    with open(p, "r") as f:
                        data = json.load(f)
                    if isinstance(data, list):
                        df = pd.DataFrame(data)
                    elif isinstance(data, dict):
                        df = pd.json_normalize(data)
                    else:
                        continue
                # Normalize column names (keep original but make lower-case mapping handy)
                df.columns = [c if isinstance(c, str) else str(c) for c in df.columns]
                # ensure epoch column exists
                if "epoch" not in df.columns:
                    df.insert(0, "epoch", range(len(df)))
                return df, p
            except Exception:
                continue
    return None, None

def pick_columns(df):
    cols_lower = [c.lower() for c in df.columns]
    loss_cols = [c for c in df.columns if "loss" in c.lower() and df[c].dtype.kind in "fiu"]
    train_loss_cols = [c for c in loss_cols if "val" not in c.lower() and "test" not in c.lower()]
    val_loss_cols = [c for c in loss_cols if "val" in c.lower() or "test" in c.lower()]
    # mAP@0.5
    map50_cols = [c for c in df.columns if "map50" in c.lower() or "m_ap_50" in c.lower() or ("map" in c.lower() and "50" in c.lower())]
    # generic map
    map_cols = [c for c in df.columns if (c.lower().startswith("map") and c not in map50_cols)]
    # IoU
    iou_cols = [c for c in df.columns if "iou" in c.lower() and df[c].dtype.kind in "fiu"]
    # other useful components (box/cls/seg)
    box_cols = [c for c in df.columns if "box" in c.lower() and df[c].dtype.kind in "fiu"]
    cls_cols = [c for c in df.columns if "cls" in c.lower() and df[c].dtype.kind in "fiu"]
    seg_cols = [c for c in df.columns if "seg" in c.lower() and df[c].dtype.kind in "fiu" and "loss" not in c.lower()]
    return {
        "loss": loss_cols,
        "train_loss": train_loss_cols,
        "val_loss": val_loss_cols,
        "map50": map50_cols,
        "map": map_cols,
        "iou": iou_cols,
        "box": box_cols,
        "cls": cls_cols,
        "seg": seg_cols
    }

def plot_run(df, label):
    epoch = df["epoch"] if "epoch" in df.columns else range(len(df))
    cols = pick_columns(df)

    plotted = False
    loss_to_plot = []
    if cols["train_loss"]:
        loss_to_plot += cols["train_loss"]
    if cols["val_loss"]:
        # show val losses as dashed
        loss_to_plot += cols["val_loss"]
    # if no explicit train/val split, plot all loss columns
    if not loss_to_plot and cols["loss"]:
        loss_to_plot = cols["loss"]

    if loss_to_plot:
        plt.figure(figsize=(9,4))
        for c in loss_to_plot:
            style = "--" if "val" in c.lower() or "test" in c.lower() else "-"
            try:
                plt.plot(epoch, df[c], linestyle=style, marker=None, label=c)
            except Exception:
                continue
        plt.title(f"{label} — Loss curves")
        plt.xlabel("epoch"); plt.ylabel("loss"); plt.grid(True); plt.legend(loc="upper right", fontsize="small")
        plt.show()
        plotted = True

    # 2) mAP@0.5
    if cols["map50"]:
        plt.figure(figsize=(9,4))
        for c in cols["map50"]:
            try:
                plt.plot(epoch, df[c], label=c, marker=None)
            except Exception:
                continue
        plt.title(f"{label} — mAP@0.5")
        plt.xlabel("epoch"); plt.ylabel("mAP@0.5"); plt.grid(True); plt.legend(loc="lower right", fontsize="small")
        plt.show()
        plotted = True
    elif cols["map"]:
        plt.figure(figsize=(9,4))
        for c in cols["map"]:
            try:
                plt.plot(epoch, df[c], label=c)
            except Exception:
                continue
        plt.title(f"{label} — mAP curve")
        plt.xlabel("epoch"); plt.ylabel("mAP"); plt.grid(True); plt.legend(loc="lower right", fontsize="small")
        plt.show()
        plotted = True

    # 3) IoU
    if cols["iou"]:
        plt.figure(figsize=(9,4))
        for c in cols["iou"]:
            try:
                plt.plot(epoch, df[c], label=c)
            except Exception:
                continue
        plt.title(f"{label} — IoU")
        plt.xlabel("epoch"); plt.ylabel("IoU"); plt.grid(True); plt.legend(loc="lower right", fontsize="small")
        plt.show()
        plotted = True

    comp_cols = cols["box"] + cols["cls"] + cols["seg"]
    # remove duplicates and already plotted loss columns
    comp_cols = [c for c in dict.fromkeys(comp_cols) if c not in (cols["loss"] + cols["train_loss"] + cols["val_loss"])]
    if comp_cols:
        plt.figure(figsize=(9,4))
        for c in comp_cols:
            try:
                plt.plot(epoch, df[c], label=c)
            except Exception:
                continue
        plt.title(f"{label} — component metrics (box/cls/seg)")
        plt.xlabel("epoch"); plt.grid(True); plt.legend(loc="upper right", fontsize="small")
        plt.show()
        plotted = True

    if not plotted:
        print(f"{label}: no plotting columns (loss / mAP@0.5 / IoU / box/cls/seg) found in metrics file.")

def final_row_from_df(df):
    if df is None or df.shape[0] == 0:
        return {}
    # use last row by epoch (max epoch) if epoch exists, else last index
    if "epoch" in df.columns:
        last_idx = int(df["epoch"].astype(int).idxmax())
    else:
        last_idx = df.index[-1]
    row = df.iloc[last_idx].to_dict()
    out = {}
    # search keys for mAP50, map, iou, and loss
    for k,v in row.items():
        kl = k.lower()
        if any(x in kl for x in ("map50","m_ap_50","map_50")) and pd.notna(v):
            out["mAP50"] = float(v)
        if kl.startswith("map") and "50" not in kl and pd.notna(v):
            # generic mAP
            out.setdefault("mAP", float(v))
            out.setdefault("IoU", float(v))
        if kl == "loss" and pd.notna(v):
            out.setdefault("loss", float(v))
        if "loss" in kl and "val" not in kl and pd.notna(v):
            out.setdefault("loss", float(v))
    return out

run_dirs = find_run_dirs(RUN_BASES, TARGET_RUN_NAME)
if not run_dirs:
    raise FileNotFoundError(f"No run directories named '{TARGET_RUN_NAME}' found under {RUN_BASES}")

summary_rows = []
print("Found runs:")
for r in run_dirs:
    print(" -", r)

for r in run_dirs:
    label = os.path.basename(os.path.dirname(r)) + "/" + os.path.basename(r) if os.path.dirname(r) else os.path.basename(r)
    df, path = load_metrics(r)
    print(f"\n== {label} ==")
    if df is not None:
        print(f"Metrics file: {path}  — shape: {df.shape}")
        plot_run(df, label)
        final = final_row_from_df(df)
        if final:
            final_row = {"run": label, "metrics_path": os.path.basename(path)}
            final_row.update(final)
            summary_rows.append(final_row)
        else:
            summary_rows.append({"run": label, "metrics_path": os.path.basename(path)})
    else:
        print("No metrics file found for this run. Skipping plots. (If you want, re-run validation with the trained weights to produce numeric metrics.)")
        summary_rows.append({"run": label, "metrics_path": None})

summary_df = pd.DataFrame(summary_rows).fillna("")
if summary_df.shape[0] > 0:
    # reorder columns for readability
    cols = [c for c in ["run", "metrics_path", "mAP50", "mAP", "IoU", "loss"] if c in summary_df.columns]
    summary_df = summary_df[cols]
    print("\nFinal metrics summary (extracted from metrics files):")
    display(summary_df)
    summary_df.to_csv(OUT_CSV, index=False)
    print(f"Saved concise CSV: {OUT_CSV}")
else:
    print("\nNo final metrics extracted from any metrics files.")
# Out:
# Found runs:
#  - /kaggle/working/runs/segment/waste_yolov8n_seg
#
# == segment/waste_yolov8n_seg ==
# Metrics file: /kaggle/working/runs/segment/waste_yolov8n_seg/results.csv  — shape: (20, 21)
# Final metrics summary (extracted from metrics files):
#                          run metrics_path    mAP50     loss
# 0  segment/waste_yolov8n_seg  results.csv  0.45918  1.14139
# Saved concise CSV: /kaggle/working/final_metrics_summary.csv
